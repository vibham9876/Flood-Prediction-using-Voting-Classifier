# %%
# Ignoring Warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
data = pd.read_csv(r'C:\Users\Charlese patel\Music\code\flood.csv')
data
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                     3                   8                6              6
# 1                     8                   4                5              7
# 2                     3                  10                4              1
# 3                     4                   4                2              7
# 4                     3                   7                5              2
# ...                 ...                 ...              ...            ...
# 49995                 3                   7                4              7
# 49996                 3                  10                3              8
# 49997                 4                   4                5              7
# 49998                 4                   5                4              4
# 49999                 4                   5                6              3
#
#        Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0                 4              4            6          2
# 1                 7              9            1          5
# 2                 7              5            4          7
# 3                 3              4            1          4
# 4                 5              8            5          2
# ...             ...            ...          ...        ...
# 49995             5              9            4          6
# 49996             3              3            4          4
# 49997             2              1            4          5
# 49998             6              3           10          2
# 49999             5              6            5          4
#
#        AgriculturalPractices  Encroachments  ...  DrainageSystems  \
# 0                          3              2  ...               10
# 1                          5              4  ...                9
# 2                          4              9  ...                7
# 3                          6              4  ...                4
# 4                          7              5  ...                7
# ...                      ...            ...  ...              ...
# 49995                     10              4  ...                7
# 49996                      3             11  ...                8
# 49997                      6              7  ...                4
# 49998                      6             11  ...                6
# 49999                      9             10  ...                2
#
#        CoastalVulnerability  Landslides  Watersheds  \
# 0                         7           4           2
# 1                         2           6           2
# 2                         4           4           8
# 3                         2           6           6
# 4                         6           5           3
# ...                     ...         ...         ...
# 49995                     3           8           8
# 49996                     6           3           6
# 49997                     6           4           1
# 49998                     3           4           7
# 49999                     4           4           5
#
#        DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                                3                4            3
# 1                                1                1            9
# 2                                6                1            8
# 3                                8                8            6
# 4                                3                4            4
# ...                            ...              ...          ...
# 49995                            6                1            5
# 49996                            4                4            2
# 49997                            5                1            6
# 49998                            6                2            4
# 49999                            6                7            8
#
#        InadequatePlanning  PoliticalFactors  FloodProbability
# 0                       2                 6             0.450
# 1                       1                 3             0.475
# 2                       3                 6             0.515
# 3                       6                10             0.520
# 4                       3                 4             0.475
# ...                   ...               ...               ...
# 49995                   4                 2             0.535
# 49996                   4                 5             0.510
# 49997                   4                 3             0.430
# 49998                   0                11             0.515
# 49999                  10                 7             0.580
#
# [50000 rows x 21 columns]

# %%
data["FloodProbability"] = np.where(data['FloodProbability'] > 0.5, 1, 0)

# %%
data.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 3                   8                6              6
# 1                 8                   4                5              7
# 2                 3                  10                4              1
# 3                 4                   4                2              7
# 4                 3                   7                5              2
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             4              4            6          2                      3
# 1             7              9            1          5                      5
# 2             7              5            4          7                      4
# 3             3              4            1          4                      6
# 4             5              8            5          2                      7
#
#    Encroachments  ...  DrainageSystems  CoastalVulnerability  Landslides  \
# 0              2  ...               10                     7           4
# 1              4  ...                9                     2           6
# 2              9  ...                7                     4           4
# 3              4  ...                4                     2           6
# 4              5  ...                7                     6           5
#
#    Watersheds  DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0           2                            3                4            3
# 1           2                            1                1            9
# 2           8                            6                1            8
# 3           6                            8                8            6
# 4           3                            3                4            4
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   2                 6                 0
# 1                   1                 3                 0
# 2                   3                 6                 1
# 3                   6                10                 1
# 4                   3                 4                 0
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   MonsoonIntensity                 50000 non-null  int64
#  1   TopographyDrainage               50000 non-null  int64
#  2   RiverManagement                  50000 non-null  int64
#  3   Deforestation                    50000 non-null  int64
#  4   Urbanization                     50000 non-null  int64
#  5   ClimateChange                    50000 non-null  int64
#  6   DamsQuality                      50000 non-null  int64
#  7   Siltation                        50000 non-null  int64
#  8   AgriculturalPractices            50000 non-null  int64
#  9   Encroachments                    50000 non-null  int64
#  10  IneffectiveDisasterPreparedness  50000 non-null  int64
#  11  DrainageSystems                  50000 non-null  int64
#  12  CoastalVulnerability             50000 non-null  int64
#  13  Landslides                       50000 non-null  int64
#  14  Watersheds                       50000 non-null  int64
#  15  DeterioratingInfrastructure      50000 non-null  int64
#  16  PopulationScore                  50000 non-null  int64
#  17  WetlandLoss                      50000 non-null  int64
#  18  InadequatePlanning               50000 non-null  int64
#  19  PoliticalFactors                 50000 non-null  int64
#  20  FloodProbability                 50000 non-null  int32
# dtypes: int32(1), int64(20)
# memory usage: 7.8 MB

# %%
data.isna().sum()
# Out:
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64

# %%
data.shape
# Out:
# (50000, 21)

# %%
data.describe()
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# count      50000.000000        50000.000000      50000.00000   50000.000000
# mean           4.991480            4.984100          5.01594       5.008480
# std            2.236834            2.246488          2.23131       2.222743
# min            0.000000            0.000000          0.00000       0.000000
# 25%            3.000000            3.000000          3.00000       3.000000
# 50%            5.000000            5.000000          5.00000       5.000000
# 75%            6.000000            6.000000          6.00000       6.000000
# max           16.000000           18.000000         16.00000      17.000000
#
#        Urbanization  ClimateChange  DamsQuality     Siltation  \
# count  50000.000000   50000.000000  50000.00000  50000.000000
# mean       4.989060       4.988340      5.01536      4.988600
# std        2.243159       2.226761      2.24500      2.232642
# min        0.000000       0.000000      0.00000      0.000000
# 25%        3.000000       3.000000      3.00000      3.000000
# 50%        5.000000       5.000000      5.00000      5.000000
# 75%        6.000000       6.000000      6.00000      6.000000
# max       17.000000      17.000000     16.00000     16.000000
#
#        AgriculturalPractices  Encroachments  ...  DrainageSystems  \
# count           50000.000000   50000.000000  ...     50000.000000
# mean                5.006120       5.006380  ...         5.006060
# std                 2.234588       2.241633  ...         2.238107
# min                 0.000000       0.000000  ...         0.000000
# 25%                 3.000000       3.000000  ...         3.000000
# 50%                 5.000000       5.000000  ...         5.000000
# 75%                 6.000000       6.000000  ...         6.000000
# max                16.000000      18.000000  ...        17.000000
#
#        CoastalVulnerability    Landslides   Watersheds  \
# count          50000.000000  50000.000000  50000.00000
# mean               4.999920      4.984220      4.97982
# std                2.247101      2.227741      2.23219
# min                0.000000      0.000000      0.00000
# 25%                3.000000      3.000000      3.00000
# 50%                5.000000      5.000000      5.00000
# 75%                6.000000      6.000000      6.00000
# max               17.000000     16.000000     16.00000
#
#        DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# count                 50000.000000     50000.000000  50000.00000
# mean                      4.988200         4.984980      5.00512
# std                       2.231134         2.238279      2.23176
# min                       0.000000         0.000000      0.00000
# 25%                       3.000000         3.000000      3.00000
# 50%                       5.000000         5.000000      5.00000
# 75%                       6.000000         6.000000      6.00000
# max                      17.000000        19.000000     22.00000
#
#        InadequatePlanning  PoliticalFactors  FloodProbability
# count        50000.000000      50000.000000      50000.000000
# mean             4.994360          4.990520          0.469900
# std              2.230011          2.246075          0.499098
# min              0.000000          0.000000          0.000000
# 25%              3.000000          3.000000          0.000000
# 50%              5.000000          5.000000          0.000000
# 75%              6.000000          6.000000          1.000000
# max             16.000000         16.000000          1.000000
#
# [8 rows x 21 columns]

# %%
columns_of_interest=data.columns
columns_of_interest
# Out:
# Index(['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
#        'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
#        'Siltation', 'AgriculturalPractices', 'Encroachments',
#        'IneffectiveDisasterPreparedness', 'DrainageSystems',
#        'CoastalVulnerability', 'Landslides', 'Watersheds',
#        'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
#        'InadequatePlanning', 'PoliticalFactors', 'FloodProbability'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Subset the DataFrame with the selected columns
subset_df = data[columns_of_interest]

# Basic statistics
statistics = subset_df.describe()

# Histograms for each column
subset_df.hist(figsize=(20, 15), bins=20)
plt.suptitle('Histograms of the Columns', fontsize=16)
plt.show()

# %%
# Box plots for each column
plt.figure(figsize=(20, 10))
sns.boxplot(data=subset_df)
plt.xticks(rotation=70)
plt.title('Box Plots of the Columns', fontsize=16)
plt.show()

# %%
# Calculate Q1, Q3, and IQR
Q1 = subset_df.quantile(0.25)
Q3 = subset_df.quantile(0.75)
IQR = Q3 - Q1

# Define the range for outlier detection (e.g., 1.5 times IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers from the DataFrame
subset_df_no_outliers = subset_df[(subset_df >= lower_bound) & (subset_df <= upper_bound)]

# Display the DataFrame without outliers
subset_df_no_outliers
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                   3.0                 8.0              6.0            6.0
# 1                   8.0                 4.0              5.0            7.0
# 2                   3.0                10.0              4.0            1.0
# 3                   4.0                 4.0              2.0            7.0
# 4                   3.0                 7.0              5.0            2.0
# ...                 ...                 ...              ...            ...
# 49995               3.0                 7.0              4.0            7.0
# 49996               3.0                10.0              3.0            8.0
# 49997               4.0                 4.0              5.0            7.0
# 49998               4.0                 5.0              4.0            4.0
# 49999               4.0                 5.0              6.0            3.0
#
#        Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0               4.0            4.0          6.0        2.0
# 1               7.0            9.0          1.0        5.0
# 2               7.0            5.0          4.0        7.0
# 3               3.0            4.0          1.0        4.0
# 4               5.0            8.0          5.0        2.0
# ...             ...            ...          ...        ...
# 49995           5.0            9.0          4.0        6.0
# 49996           3.0            3.0          4.0        4.0
# 49997           2.0            1.0          4.0        5.0
# 49998           6.0            3.0         10.0        2.0
# 49999           5.0            6.0          5.0        4.0
#
#        AgriculturalPractices  Encroachments  ...  DrainageSystems  \
# 0                        3.0            2.0  ...             10.0
# 1                        5.0            4.0  ...              9.0
# 2                        4.0            9.0  ...              7.0
# 3                        6.0            4.0  ...              4.0
# 4                        7.0            5.0  ...              7.0
# ...                      ...            ...  ...              ...
# 49995                   10.0            4.0  ...              7.0
# 49996                    3.0            NaN  ...              8.0
# 49997                    6.0            7.0  ...              4.0
# 49998                    6.0            NaN  ...              6.0
# 49999                    9.0           10.0  ...              2.0
#
#        CoastalVulnerability  Landslides  Watersheds  \
# 0                       7.0         4.0         2.0
# 1                       2.0         6.0         2.0
# 2                       4.0         4.0         8.0
# 3                       2.0         6.0         6.0
# 4                       6.0         5.0         3.0
# ...                     ...         ...         ...
# 49995                   3.0         8.0         8.0
# 49996                   6.0         3.0         6.0
# 49997                   6.0         4.0         1.0
# 49998                   3.0         4.0         7.0
# 49999                   4.0         4.0         5.0
#
#        DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                              3.0              4.0          3.0
# 1                              1.0              1.0          9.0
# 2                              6.0              1.0          8.0
# 3                              8.0              8.0          6.0
# 4                              3.0              4.0          4.0
# ...                            ...              ...          ...
# 49995                          6.0              1.0          5.0
# 49996                          4.0              4.0          2.0
# 49997                          5.0              1.0          6.0
# 49998                          6.0              2.0          4.0
# 49999                          6.0              7.0          8.0
#
#        InadequatePlanning  PoliticalFactors  FloodProbability
# 0                     2.0               6.0                 0
# 1                     1.0               3.0                 0
# 2                     3.0               6.0                 1
# 3                     6.0              10.0                 1
# 4                     3.0               4.0                 0
# ...                   ...               ...               ...
# 49995                 4.0               2.0                 1
# 49996                 4.0               5.0                 1
# 49997                 4.0               3.0                 0
# 49998                 0.0               NaN                 1
# 49999                10.0               7.0                 1
#
# [50000 rows x 21 columns]

# %%
subset_df_no_outliers.describe()
# Out:
#        MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# count      49314.000000        49289.000000     49339.000000   49318.000000
# mean           4.899988            4.888758         4.927441       4.916744
# std            2.109915            2.113670         2.107253       2.092456
# min            0.000000            0.000000         0.000000       0.000000
# 25%            3.000000            3.000000         3.000000       3.000000
# 50%            5.000000            5.000000         5.000000       5.000000
# 75%            6.000000            6.000000         6.000000       6.000000
# max           10.000000           10.000000        10.000000      10.000000
#
#        Urbanization  ClimateChange   DamsQuality     Siltation  \
# count  49313.000000   49353.000000  49259.000000  49329.000000
# mean       4.895403       4.900898      4.916848      4.897971
# std        2.109032       2.102459      2.109441      2.104287
# min        0.000000       0.000000      0.000000      0.000000
# 25%        3.000000       3.000000      3.000000      3.000000
# 50%        5.000000       5.000000      5.000000      5.000000
# 75%        6.000000       6.000000      6.000000      6.000000
# max       10.000000      10.000000     10.000000     10.000000
#
#        AgriculturalPractices  Encroachments  ...  DrainageSystems  \
# count           49317.000000   49312.000000  ...     49269.000000
# mean                4.915364       4.914037  ...         4.907934
# std                 2.109140       2.112378  ...         2.100263
# min                 0.000000       0.000000  ...         0.000000
# 25%                 3.000000       3.000000  ...         3.000000
# 50%                 5.000000       5.000000  ...         5.000000
# 75%                 6.000000       6.000000  ...         6.000000
# max                10.000000      10.000000  ...        10.000000
#
#        CoastalVulnerability    Landslides    Watersheds  \
# count          49253.000000  49355.000000  49314.000000
# mean               4.899803      4.897802      4.886868
# std                2.107447      2.106836      2.099814
# min                0.000000      0.000000      0.000000
# 25%                3.000000      3.000000      3.000000
# 50%                5.000000      5.000000      5.000000
# 75%                6.000000      6.000000      6.000000
# max               10.000000     10.000000     10.000000
#
#        DeterioratingInfrastructure  PopulationScore   WetlandLoss  \
# count                 49337.000000     49323.000000  49326.000000
# mean                      4.899487         4.893194      4.915116
# std                       2.107192         2.107793      2.105690
# min                       0.000000         0.000000      0.000000
# 25%                       3.000000         3.000000      3.000000
# 50%                       5.000000         5.000000      5.000000
# 75%                       6.000000         6.000000      6.000000
# max                      10.000000        10.000000     10.000000
#
#        InadequatePlanning  PoliticalFactors  FloodProbability
# count        49330.000000      49278.000000      50000.000000
# mean             4.904135          4.894152          0.469900
# std              2.102628          2.112815          0.499098
# min              0.000000          0.000000          0.000000
# 25%              3.000000          3.000000          0.000000
# 50%              5.000000          5.000000          0.000000
# 75%              6.000000          6.000000          1.000000
# max             10.000000         10.000000          1.000000
#
# [8 rows x 21 columns]

# %%
subset_df_no_outliers.isnull().sum()
# Out:
# MonsoonIntensity                   686
# TopographyDrainage                 711
# RiverManagement                    661
# Deforestation                      682
# Urbanization                       687
# ClimateChange                      647
# DamsQuality                        741
# Siltation                          671
# AgriculturalPractices              683
# Encroachments                      688
# IneffectiveDisasterPreparedness    656
# DrainageSystems                    731
# CoastalVulnerability               747
# Landslides                         645
# Watersheds                         686
# DeterioratingInfrastructure        663
# PopulationScore                    677
# WetlandLoss                        674
# InadequatePlanning                 670
# PoliticalFactors                   722
# FloodProbability                     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# Define imputation strategy (median or mean)
imputation_strategy = 'mean'  # or 'mean'

# Create a SimpleImputer object with the chosen strategy
imputer = SimpleImputer(strategy=imputation_strategy)

# Iterate over each column in the DataFrame
for column in subset_df_no_outliers.columns:
    # Skip the 'FloodProbability' column
    if column == 'FloodProbability':
        continue
    
    # Impute missing values in the current column
    subset_df_no_outliers[column] = imputer.fit_transform(subset_df_no_outliers[[column]])

# Check if there are any remaining missing values after imputation
print(subset_df_no_outliers.isnull().sum())
# Out:
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64
